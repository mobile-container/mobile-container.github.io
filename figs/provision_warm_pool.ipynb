# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

from matplotlib.colors import LogNorm

import os

import time



csv_filename = 'random_latency_data.csv'



# =====================================================================

# 第二部分：读取 CSV 进行可视化 (全大字体、正方形Block、极简坐标轴)

# =====================================================================

# 1. 样式与超大字体全局设置

sns.set_theme(style="white")

plt.rcParams.update({

    'font.size': 40,

    'axes.labelsize': 64,

    'axes.titlesize': 64,

    'xtick.labelsize': 32,

    'ytick.labelsize': 32,

    'font.weight': 'normal',

    'axes.labelweight': 'normal',

    'axes.titleweight': 'normal'

})



t0 = time.time()

print(f"[plot] start, reading csv={csv_filename}")



# 2. 读取数据

DATA_ROWS = [{'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 1, 'Metric': 'Mean Latency', 'Latency': 0.0345158141216457}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 1, 'Metric': 'P95 Latency', 'Latency': 0.0345158141216457}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 2, 'Metric': 'Mean Latency', 'Latency': 0.0342383428362261}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 2, 'Metric': 'P95 Latency', 'Latency': 0.0345795235888091}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 4, 'Metric': 'Mean Latency', 'Latency': 0.036607146495431}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 4, 'Metric': 'P95 Latency', 'Latency': 0.0371389950346426}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 8, 'Metric': 'Mean Latency', 'Latency': 0.0341381527408816}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 8, 'Metric': 'P95 Latency', 'Latency': 0.0348223573226484}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 15, 'Metric': 'Mean Latency', 'Latency': 0.0359557464019486}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 15, 'Metric': 'P95 Latency', 'Latency': 0.0367502978530357}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 16, 'Metric': 'Mean Latency', 'Latency': 0.0366827592812215}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 16, 'Metric': 'P95 Latency', 'Latency': 0.0374866858118303}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 20, 'Metric': 'Mean Latency', 'Latency': 0.0358364166421126}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 20, 'Metric': 'P95 Latency', 'Latency': 0.0366430326332706}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 32, 'Metric': 'Mean Latency', 'Latency': 0.0360271984876635}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 32, 'Metric': 'P95 Latency', 'Latency': 0.0368894927273507}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 60, 'Metric': 'Mean Latency', 'Latency': 0.0330772370731529}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 60, 'Metric': 'P95 Latency', 'Latency': 0.0339455493263136}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 62, 'Metric': 'Mean Latency', 'Latency': 1.92729615040562}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 62, 'Metric': 'P95 Latency', 'Latency': 0.0345401567592993}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 64, 'Metric': 'Mean Latency', 'Latency': 4.606035622527089}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 64, 'Metric': 'P95 Latency', 'Latency': 49.305141376906}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 128, 'Metric': 'Mean Latency', 'Latency': 634.5532834018221}, {'System': 'Anbox Cloud', 'Profiles': 1, 'Concurrency': 128, 'Metric': 'P95 Latency', 'Latency': 2115.081559930348}, {'System': 'Anbox Cloud', 'Profiles': 5, 'Concurrency': 1, 'Metric': 'Mean Latency', 'Latency': 0.0360911837638935}, {'System': 'Anbox Cloud', 'Profiles': 5, 'Concurrency': 1, 'Metric': 'P95 Latency', 'Latency': 0.0360911837638935}, {'System': 'Anbox Cloud', 'Profiles': 5, 'Concurrency': 2, 'Metric': 'Mean Latency', 'Latency': 0.0354960743485466}, {'System': 'Anbox Cloud', 'Profiles': 5, 'Concurrency': 2, 'Metric': 'P95 Latency', 'Latency': 0.0357882132149726}, {'System': 'Anbox Cloud', 'Profiles': 5, 'Concurrency': 4, 'Metric': 'Mean Latency', 'Latency': 0.0364829547382062}, {'System': 'Anbox Cloud', 'Profiles': 5, 'Concurrency': 4, 'Metric': 'P95 Latency', 'Latency': 0.037034361716996}, {'System': 'Anbox Cloud', 'Profiles': 5, 'Concurrency': 8, 'Metric': 'Mean Latency', 'Latency': 0.0367694397555162}, {'System': 'Anbox Cloud', 'Profiles': 5, 'Concurrency': 8, 'Metric': 'P95 Latency', 'Latency': 0.037454272271035}, {'System': 'Anbox Cloud', 'Profiles': 5, 'Concurrency': 15, 'Metric': 'Mean Latency', 'Latency': 0.0346071057992704}, {'System': 'Anbox Cloud', 'Profiles': 5, 'Concurrency': 15, 'Metric': 'P95 Latency', 'Latency':
 'Concurrency': 4, 'Metric': 'Mean Latency', 'Latency': 1.91822729339902}, {'System': 'Anbox Cloud', 'Profiles': 50, 'Concurrency': 4, 'Metric': 'P95 Latency', 'Latency': 6.440048774853022}, {'System': 'Anbox Cloud', 'Profiles': 50, 'Concurrency': 8, 'Metric': 'Mean Latency', 'Latency': 3.30259448753774}, {'System': 'Anbox Cloud', 'Profiles': 50, 'Concurrency': 8, 'Metric': 'P95 Latency', 'Latency': 16.49853643980563}, {'System': 'Anbox Cloud', 'Profiles': 50, 'Concurrency': 15, 'Metric': 'Mean Latency', 'Latency': 7.1527111249649975}, {'System': 'Anbox Cloud', 'Profiles': 50, 'Concurrency': 15, 'Metric': 'P95 Latency', 'Latency': 39.273593903478}, {'System': 'Anbox Cloud', 'Profiles': 50, 'Concurrency': 16, 'Metric': 'Mean Latency', 'Latency': 6.261596157172872}, {'System': 'Anbox Cloud', 'Profiles': 50, 'Concurrency': 16, 'Metric': 'P95 Latency', 'Latency': 37.46313335048024}, {'System': 'Anbox Cloud', 'Profiles': 50, 'Concurrency': 20, 'Metric': 'Mean Latency', 'Latency': 9.28088672206384}, {'System': 'Anbox Cloud', 'Profiles': 50, 'Concurrency': 20, 'Metric': 'P95 Latency', 'Latency': 57.85501820464687}, {'System': 'Anbox Cloud', 'Profiles': 50, 'Concurrency': 32, 'Metric': 'Mean Latency', 'Latency': 22.63162393180031}, {'System': 'Anbox Cloud', 'Profiles': 50, 'Concurrency': 32, 'Metric': 'P95 Latency', 'Latency': 118.32595030948885}, {'System': 'Anbox Cloud', 'Profiles': 50, 'Concurrency': 60, 'Metric': 'Mean Latency', 'Latency': 87.68974007602772}, {'System': 'Anbox Cloud', 'Profiles': 50, 'Concurrency': 60, 'Metric': 'P95 Latency', 'Latency': 371.17196092231984}, {'System': 'Anbox Cloud', 'Profiles': 50, 'Concurrency': 62, 'Metric': 'Mean Latency', 'Latency': 99.74471272695676}, {'System': 'Anbox Cloud', 'Profiles': 50, 'Concurrency': 62, 'Metric': 'P95 Latency', 'Latency': 415.26337640941495}, {'System': 'Anbox Cloud', 'Profiles': 50, 'Concurrency': 64, 'Metric': 'Mean Latency', 'Latency': 105.80112228087393}, {'System': 'Anbox Cloud', 'Profiles': 50, 'Concurrency': 64, 'Metric': 'P95 Latency', 'Latency': 441.18935052701227}, {'System': 'Anbox Cloud', 'Profiles': 50, 'Concurrency': 128, 'Metric': 'Mean Latency', 'Latency': 757.484389715673}, {'System': 'Anbox Cloud', 'Profiles': 50, 'Concurrency': 128, 'Metric': 'P95 Latency', 'Latency': 2331.8193091123658}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 1, 'Metric': 'Mean Latency', 'Latency': 26.11996996333553}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 1, 'Metric': 'P95 Latency', 'Latency': 26.11996996333553}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 2, 'Metric': 'Mean Latency', 'Latency': 20.700811899424203}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 2, 'Metric': 'P95 Latency', 'Latency': 33.04034066901661}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 4, 'Metric': 'Mean Latency', 'Latency': 27.52744022572522}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 4, 'Metric': 'P95 Latency', 'Latency': 51.92455714169805}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 8, 'Metric': 'Mean Latency', 'Latency': 30.82957758435663}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 8, 'Metric': 'P95 Latency', 'Latency': 73.68529766369619}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 15, 'Metric': 'Mean Latency', 'Latency': 43.41397585149934}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 15, 'Metric': 'P95 Latency', 'Latency': 121.11338297963998}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 16, 'Metric': 'Mean Latency', 'Latency': 41.35779806352629}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 16, 'Metric': 'P95 Latency', 'Latency': 121.18733440102363}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 20, 'Metric': 'Mean Latency', 'Latency': 56.13601396936741}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 20, 'Metric': 'P95 Latency', 'Latency': 162.11820872019032}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 32, 'Metric': 'Mean Latency', 'Latency': 85.25767956471996}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 32, 'Metric': 'P95 Latency', 'Latency': 268.69282831192066}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 60, 'Metric': 'Mean Latency', 'Latency': 237.76046792506307}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 60, 'Metric': 'P95 Latency', 'Latency': 725.3178920036291}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 62, 'Metric': 'Mean Latency', 'Latency': 238.27017010108423}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 62, 'Metric': 'P95 Latency', 'Latency': 737.8454629585905}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 64, 'Metric': 'Mean Latency', 'Latency': 261.5303530769736}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 64, 'Metric': 'P95 Latency', 'Latency': 787.9585622627769}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 128, 'Metric': 'Mean Latency', 'Latency': 964.1798362121684}, {'System': 'Anbox Cloud', 'Profiles': 100, 'Concurrency': 128, 'Metric': 'P95 Latency', 'Latency': 2660.015237815025}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 1, 'Metric': 'Mean Latency', 'Latency': 53.94255645694771}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 1, 'Metric': 'P95 Latency', 'Latency': 53.94255645694771}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 2, 'Metric': 'Mean Latency', 'Latency': 54.87441446741709}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 2, 'Metric': 'P95 Latency', 'Latency': 58.843149446741705}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 4, 'Metric': 'Mean Latency', 'Latency': 59.78376926259487}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 4, 'Metric': 'P95 Latency', 'Latency': 76.34314902333993}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 8, 'Metric': 'Mean Latency', 'Latency': 87.16571771124795}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 8, 'Metric': 'P95 Latency', 'Latency': 133.15675139898966}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 15, 'Metric': 'Mean Latency', 'Latency': 139.18082347258033}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 15, 'Metric': 'P95 Latency', 'Latency': 244.94905392175363}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 16, 'Metric': 'Mean Latency', 'Latency': 151.05592699091957}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 16, 'Metric': 'P95 Latency', 'Latency': 268.3493438326127}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 20, 'Metric': 'Mean Latency', 'Latency': 182.08238961572468}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 20, 'Metric': 'P95 Latency', 'Latency': 331.53810515858845}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 32, 'Metric': 'Mean Latency', 'Latency': 323.52305724621243}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 32, 'Metric': 'P95 Latency', 'Latency': 637.643428751958}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 60, 'Metric': 'Mean Latency', 'Latency': 841.1766518151298}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 60, 'Metric': 'P95 Latency', 'Latency': 1729.061662271674}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 62, 'Metric': 'Mean Latency', 'Latency': 861.3323299165859}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 62, 'Metric': 'P95 Latency', 'Latency': 1781.133550745965}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 64, 'Metric': 'Mean Latency', 'Latency': 907.4010403169002}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 64, 'Metric': 'P95 Latency', 'Latency': 1859.7953008738075}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 128, 'Metric': 'Mean Latency', 'Latency': 1771.628784822415}, {'System': 'Anbox Cloud', 'Profiles': 500, 'Concurrency': 128, 'Metric': 'P95 Latency', 'Latency': 3689.1807655101416}, {'System': 'Anbox Cloud', 'Profiles': 1000, 'Concurrency': 1, 'Metric': 'Mean Latency', 'Latency': 52.20331821342175}, {'System': 'Anbox Cloud', 'Profiles': 1000, 'Concurrency': 1, 'Metric': 'P95 Latency', 'Latency': 52.20331821342175}, {'System': 'Anbox Cloud', 'Profiles': 1000, 'Concurrency': 2, 'Metric': 'Mean Latency', 'Latency': 54.57717663097326}, {'System': 'Anbox Cloud', 'Profiles': 1000, 'Concurrency': 2, 'Metric': 'P95 Latency', 'Latency': 58.80014166309733}, {'System': 'Anbox Cloud', 'Profiles': 1000, 'Concurrency': 4, 'Metric': 'Mean Latency', 'Latency': 66.60470917961264}, {'System': 'Anbox Cloud', 'Profiles': 1000, 'Concurrency': 4, 'Metric': 'P95 Latency', 'Latency': 81.25094154341889}, {'System': 'Anbox Cloud', 'Profiles': 1000, 'Concurrency': 8, 'Metric': 'Mean Latency', 'Latency': 96.94715922055592}, {'System': 'Anbox Cloud', 'Profiles': 1000, 'Concurrency': 8, 'Metric': 'P95 Latency', 'Latency': 143.10214158744392}, {'System': 'Anbox Cloud', 'Profiles': 1000, 'Concurrency': 15, 'Metric': 'Mean Latency', 'Latency': 161.50488511435844}, {'System': 'Anbox Cloud', 'Profiles': 1000, 'Concurrency': 15, 'Metric': 'P95 Latency', 'Latency': 270.6614715490657}, {'System': 'Anbox Cloud', 'Profiles': 1000, 'Concurrency': 16, 'Metric': 'Mean Latency', 'Latency': 168.2021979111831}, {'System': 'Anbox Cloud', 'Profiles': 1000, 'Concurrency': 16, 'Metric': 'P95 Latency', 'Latency': 285.0915757884686}, {'System': 'Anbox Cloud', 'Profiles': 1000, 'Concurrency': 20, 'Metric': 'Mean Latency', 'Latency': 198.69489287895937}, {'System': 'Anbox Cloud', 'Profiles': 1000, 'Concurrency': 20, 'Metric': 'P95 Latency', 'Latency': 347.7007822758045}, {'System': 'Anbox Cloud', 'Profiles': 1000, 'Concurrency': 32, 'Metric': 'Mean Latency', 'Latency': 368.28353257684086}, {'System': 'Anbox Cloud', 'Profiles': 1000, 'Concurrency': 32, 'Metric': 'P95 Latency', 'Latency': 686.0484349434347}, {'System': 'Anbox Cloud', 'Profiles': 1000, 'Concurrency': 60, 'Metric': 'Mean Latency', 'Latency': 941.2179543587416}, {'System': 'Anbox Cloud', 'Profiles': 1000, 'Concurrency': 60, 'Metric': 'P95 Latency', 'Latency':
 'Concurrency': 62, 'Metric': 'Mean Latency', 'Latency': 9.953109413834552}, {'System': 'GAE', 'Profiles': 50, 'Concurrency': 62, 'Metric': 'P95 Latency', 'Latency': 33.99998151945373}, {'System': 'GAE', 'Profiles': 50, 'Concurrency': 64, 'Metric': 'Mean Latency', 'Latency': 10.176663930949644}, {'System': 'GAE', 'Profiles': 50, 'Concurrency': 64, 'Metric': 'P95 Latency', 'Latency': 34.53991159819516}, {'System': 'GAE', 'Profiles': 50, 'Concurrency': 128, 'Metric': 'Mean Latency', 'Latency': 26.00229187601229}, {'System': 'GAE', 'Profiles': 50, 'Concurrency': 128, 'Metric': 'P95 Latency', 'Latency': 64.6096055395673}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 1, 'Metric': 'Mean Latency', 'Latency': 5.968969963335533}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 1, 'Metric': 'P95 Latency', 'Latency': 5.968969963335533}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 2, 'Metric': 'Mean Latency', 'Latency': 4.723751899424201}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 2, 'Metric': 'P95 Latency', 'Latency': 7.520166669016606}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 4, 'Metric': 'Mean Latency', 'Latency': 6.060961417259493}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 4, 'Metric': 'P95 Latency', 'Latency': 11.405192861352647}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 8, 'Metric': 'Mean Latency', 'Latency': 5.8139685894811945}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 8, 'Metric': 'P95 Latency', 'Latency': 13.404098143777892}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 15, 'Metric': 'Mean Latency', 'Latency': 6.316980128355611}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 15, 'Metric': 'P95 Latency', 'Latency': 15.352358174037567}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 16, 'Metric': 'Mean Latency', 'Latency': 5.993302914918515}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 16, 'Metric': 'P95 Latency', 'Latency': 15.238603205883244}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 20, 'Metric': 'Mean Latency', 'Latency': 7.623757155240301}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 20, 'Metric': 'P95 Latency', 'Latency': 17.452812556492383}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 32, 'Metric': 'Mean Latency', 'Latency': 10.923946825120083}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 32, 'Metric': 'P95 Latency', 'Latency': 26.679617220616333}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 60, 'Metric': 'Mean Latency', 'Latency': 17.191467661390767}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 60, 'Metric': 'P95 Latency', 'Latency': 40.695827508707154}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 62, 'Metric': 'Mean Latency', 'Latency': 17.084955112641964}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 62, 'Metric': 'P95 Latency', 'Latency': 41.0607261655616}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 64, 'Metric': 'Mean Latency', 'Latency': 18.14130579444604}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 64, 'Metric': 'P95 Latency', 'Latency': 42.45869691215995}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 128, 'Metric': 'Mean Latency', 'Latency': 31.458295408980327}, {'System': 'GAE', 'Profiles': 100, 'Concurrency': 128, 'Metric': 'P95 Latency', 'Latency': 70.77106692012893}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 1, 'Metric': 'Mean Latency', 'Latency': 12.29715645694771}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 1, 'Metric': 'P95 Latency', 'Latency': 12.29715645694771}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 2, 'Metric': 'Mean Latency', 'Latency': 12.423954467417088}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 2, 'Metric': 'P95 Latency', 'Latency': 13.250015446741708}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 4, 'Metric': 'Mean Latency', 'Latency': 11.411048516478978}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 4, 'Metric': 'P95 Latency', 'Latency': 13.698200507802394}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 8, 'Metric': 'Mean Latency', 'Latency': 12.4884010809478}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 8, 'Metric': 'P95 Latency', 'Latency': 15.925153166085943}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 15, 'Metric': 'Mean Latency', 'Latency': 19.01328352230975}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 15, 'Metric': 'P95 Latency', 'Latency': 23.74664590953496}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 16, 'Metric': 'Mean Latency', 'Latency': 20.106181083927197}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 16, 'Metric': 'P95 Latency', 'Latency': 26.234034148555693}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 20, 'Metric': 'Mean Latency', 'Latency': 22.07241882452143}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 20, 'Metric': 'P95 Latency', 'Latency': 31.96724489886682}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 32, 'Metric': 'Mean Latency', 'Latency': 25.586799776179745}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 32, 'Metric': 'P95 Latency', 'Latency': 38.36588910302356}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 60, 'Metric': 'Mean Latency', 'Latency': 33.65099271466002}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 60, 'Metric': 'P95 Latency', 'Latency': 53.46438975280544}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 62, 'Metric': 'Mean Latency', 'Latency': 33.918492776349886}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 62, 'Metric': 'P95 Latency', 'Latency': 54.3444950404681}, {'System': 'GAE', 'Profiles': 500, 'Concurrency': 64, 'Metric': 'Mean Latency', 'Latency':
 'Concurrency': 128, 'Metric': 'Mean Latency', 'Latency': 307.99156638743943}, {'System': 'Redroid', 'Profiles': 500, 'Concurrency': 128, 'Metric': 'P95 Latency', 'Latency': 615.486646277218}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 1, 'Metric': 'Mean Latency', 'Latency': 14.401518213421747}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 1, 'Metric': 'P95 Latency', 'Latency': 14.401518213421747}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 2, 'Metric': 'Mean Latency', 'Latency': 15.578956630973268}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 2, 'Metric': 'P95 Latency', 'Latency': 17.17591966309733}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 4, 'Metric': 'Mean Latency', 'Latency': 18.897159525253564}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 4, 'Metric': 'P95 Latency', 'Latency': 22.262147146231477}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 8, 'Metric': 'Mean Latency', 'Latency': 40.33889381543569}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 8, 'Metric': 'P95 Latency', 'Latency': 43.6550114265025}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 15, 'Metric': 'Mean Latency', 'Latency': 32.79619192053615}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 15, 'Metric': 'P95 Latency', 'Latency': 39.254666708923246}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 16, 'Metric': 'Mean Latency', 'Latency': 32.76802502992206}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 16, 'Metric': 'P95 Latency', 'Latency': 39.73586420913751}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 20, 'Metric': 'Mean Latency', 'Latency': 33.90723793366607}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 20, 'Metric': 'P95 Latency', 'Latency': 42.383651834835874}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 32, 'Metric': 'Mean Latency', 'Latency': 105.68885589385371}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 32, 'Metric': 'P95 Latency', 'Latency': 202.5252215}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 60, 'Metric': 'Mean Latency', 'Latency': 173.87060961401767}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 60, 'Metric': 'P95 Latency', 'Latency': 315.0420375}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 62, 'Metric': 'Mean Latency', 'Latency': 178.61724087997715}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 62, 'Metric': 'P95 Latency', 'Latency': 321.78462}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 64, 'Metric': 'Mean Latency', 'Latency': 183.2651535734093}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 64, 'Metric': 'P95 Latency', 'Latency': 330.19805699999995}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 128, 'Metric': 'Mean Latency', 'Latency': 341.0100611577608}, {'System': 'Redroid', 'Profiles': 1000, 'Concurrency': 128, 'Metric': 'P95 Latency', 'Latency': 647.8978324040926}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 1, 'Metric': 'Mean Latency', 'Latency': 0.0345158141216457}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 1, 'Metric': 'P95 Latency', 'Latency': 0.0345158141216457}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 2, 'Metric': 'Mean Latency', 'Latency': 0.0342383428362261}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 2, 'Metric': 'P95 Latency', 'Latency': 0.0345795235888091}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 4, 'Metric': 'Mean Latency', 'Latency': 0.036607146495431}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 4, 'Metric': 'P95 Latency', 'Latency': 0.0371389950346426}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 8, 'Metric': 'Mean Latency', 'Latency': 0.0341381527408816}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 8, 'Metric': 'P95 Latency', 'Latency': 0.0348223573226484}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 15, 'Metric': 'Mean Latency', 'Latency': 0.0359557464019486}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 15, 'Metric': 'P95 Latency', 'Latency': 0.0367502978530357}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 16, 'Metric': 'Mean Latency', 'Latency': 0.0366827592812215}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 16, 'Metric': 'P95 Latency', 'Latency': 0.0374866858118303}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 20, 'Metric': 'Mean Latency', 'Latency': 0.0358364166421126}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 20, 'Metric': 'P95 Latency', 'Latency': 0.0366430326332706}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 32, 'Metric': 'Mean Latency', 'Latency': 0.0360271984876635}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 32, 'Metric': 'P95 Latency', 'Latency': 0.0368894927273507}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 60, 'Metric': 'Mean Latency', 'Latency': 0.0330772370731529}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 60, 'Metric': 'P95 Latency', 'Latency': 0.0339455493263136}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 62, 'Metric': 'Mean Latency', 'Latency': 0.6487316342765879}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 62, 'Metric': 'P95 Latency', 'Latency': 0.0345401567592993}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 64, 'Metric': 'Mean Latency', 'Latency': 1.0835092190164266}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 64, 'Metric': 'P95 Latency', 'Latency': 11.10444137690626}, {'System': 'vSoC', 'Profiles': 1, 'Concurrency': 128, 'Metric': 'Mean Latency', 'Latency':
 'Concurrency': 64, 'Metric': 'P95 Latency', 'Latency': 21.214086130367228}, {'System': 'vSoC', 'Profiles': 10, 'Concurrency': 128, 'Metric': 'Mean Latency', 'Latency': 26.278145787228745}, {'System': 'vSoC', 'Profiles': 10, 'Concurrency': 128, 'Metric': 'P95 Latency', 'Latency': 73.02845211603736}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 1, 'Metric': 'Mean Latency', 'Latency': 0.0342906369899909}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 1, 'Metric': 'P95 Latency', 'Latency': 0.0342906369899909}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 2, 'Metric': 'Mean Latency', 'Latency': 0.5152549152504637}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 2, 'Metric': 'P95 Latency', 'Latency': 0.9489224624186297}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 4, 'Metric': 'Mean Latency', 'Latency': 0.8168347933990201}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 4, 'Metric': 'P95 Latency', 'Latency': 2.6953142748530223}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 8, 'Metric': 'Mean Latency', 'Latency': 1.3532394875377405}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 8, 'Metric': 'P95 Latency', 'Latency': 6.732411439805637}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 15, 'Metric': 'Mean Latency', 'Latency': 2.430943791965226}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 15, 'Metric': 'P95 Latency', 'Latency': 13.250343625972178}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 16, 'Metric': 'Mean Latency', 'Latency': 2.005047182527639}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 16, 'Metric': 'P95 Latency', 'Latency': 11.649321280067}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 20, 'Metric': 'Mean Latency', 'Latency': 2.6666579959950854}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 20, 'Metric': 'P95 Latency', 'Latency': 16.248203070404823}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 32, 'Metric': 'Mean Latency', 'Latency': 3.780093277468599}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 32, 'Metric': 'P95 Latency', 'Latency': 19.06710256825444}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 60, 'Metric': 'Mean Latency', 'Latency': 10.003986559025748}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 60, 'Metric': 'P95 Latency', 'Latency': 35.17910172131861}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 62, 'Metric': 'Mean Latency', 'Latency': 10.612468472642115}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 62, 'Metric': 'P95 Latency', 'Latency': 36.72130279760613}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 64, 'Metric': 'Mean Latency', 'Latency': 10.877894524015751}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 64, 'Metric': 'P95 Latency', 'Latency': 37.97189312082261}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 128, 'Metric': 'Mean Latency', 'Latency': 30.24151757086125}, {'System': 'vSoC', 'Profiles': 50, 'Concurrency': 128, 'Metric': 'P95 Latency', 'Latency': 78.21936850314817}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 1, 'Metric': 'Mean Latency', 'Latency': 10.869919963335532}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 1, 'Metric': 'P95 Latency', 'Latency': 10.869919963335532}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 2, 'Metric': 'Mean Latency', 'Latency': 7.9806368994242}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 2, 'Metric': 'P95 Latency', 'Latency': 13.318260169016606}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 4, 'Metric': 'Mean Latency', 'Latency': 9.236028180428772}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 4, 'Metric': 'P95 Latency', 'Latency': 19.2858938561282}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 8, 'Metric': 'Mean Latency', 'Latency': 8.081726547771478}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 8, 'Metric': 'P95 Latency', 'Latency': 21.572743526887365}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 15, 'Metric': 'Mean Latency', 'Latency': 7.382016181664382}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 15, 'Metric': 'P95 Latency', 'Latency': 20.94946120626626}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 16, 'Metric': 'Mean Latency', 'Latency': 7.083531188401488}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 16, 'Metric': 'P95 Latency', 'Latency': 21.087011761601307}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 20, 'Metric': 'Mean Latency', 'Latency': 8.408026547247015}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 20, 'Metric': 'P95 Latency', 'Latency': 23.928269565372705}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 32, 'Metric': 'Mean Latency', 'Latency': 9.438349447427123}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 32, 'Metric': 'P95 Latency', 'Latency': 24.978002517152536}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 60, 'Metric': 'Mean Latency', 'Latency': 18.84569878074652}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 60, 'Metric': 'P95 Latency', 'Latency': 46.63443765745123}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 62, 'Metric': 'Mean Latency', 'Latency': 18.75010515329345}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 62, 'Metric': 'P95 Latency', 'Latency': 47.0936767342964}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 64, 'Metric': 'Mean Latency', 'Latency': 20.00922522478482}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 64, 'Metric': 'P95 Latency', 'Latency': 48.93192898639274}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 128, 'Metric': 'Mean Latency', 'Latency': 36.90240236192956}, {'System': 'vSoC', 'Profiles': 100, 'Concurrency': 128, 'Metric': 'P95 Latency', 'Latency': 86.33226026877468}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 1, 'Metric': 'Mean Latency', 'Latency': 22.425786456947712}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 1, 'Metric': 'P95 Latency', 'Latency': 22.425786456947712}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 2, 'Metric': 'Mean Latency', 'Latency': 18.188744467417088}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 2, 'Metric': 'P95 Latency', 'Latency': 21.375703446741703}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 4, 'Metric': 'Mean Latency', 'Latency': 15.674131237192364}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 4, 'Metric': 'P95 Latency', 'Latency': 22.4678202582279}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 8, 'Metric': 'Mean Latency', 'Latency': 13.976509051855915}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 8, 'Metric': 'P95 Latency', 'Latency': 21.036738614808147}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 15, 'Metric': 'Mean Latency', 'Latency': 15.838964679579384}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 15, 'Metric': 'P95 Latency', 'Latency': 23.815051933068773}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 16, 'Metric': 'Mean Latency', 'Latency': 15.700089297797868}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 16, 'Metric': 'P95 Latency', 'Latency': 22.50337748845136}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 20, 'Metric': 'Mean Latency', 'Latency': 21.134974020287878}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 20, 'Metric': 'P95 Latency', 'Latency': 31.002773132743236}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 32, 'Metric': 'Mean Latency', 'Latency': 27.692039454864226}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 32, 'Metric': 'P95 Latency', 'Latency': 43.532318040225526}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 60, 'Metric': 'Mean Latency', 'Latency': 38.18234731450575}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 60, 'Metric': 'P95 Latency', 'Latency': 63.46393522585545}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 62, 'Metric': 'Mean Latency', 'Latency': 38.573202923611696}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 62, 'Metric': 'P95 Latency', 'Latency': 64.64523351348014}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 64, 'Metric': 'Mean Latency', 'Latency': 39.94144569241915}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 64, 'Metric': 'P95 Latency', 'Latency': 66.56398729640873}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 128, 'Metric': 'Mean Latency', 'Latency': 61.72871560683471}, {'System': 'vSoC', 'Profiles': 500, 'Concurrency': 128, 'Metric': 'P95 Latency', 'Latency': 111.7785554308782}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 1, 'Metric': 'Mean Latency', 'Latency': 21.703218213421746}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 1, 'Metric': 'P95 Latency', 'Latency': 21.703218213421746}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 2, 'Metric': 'Mean Latency', 'Latency': 18.118416630973265}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 2, 'Metric': 'P95 Latency', 'Latency': 21.39330366309732}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 4, 'Metric': 'Mean Latency', 'Latency': 16.531523206292807}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 4, 'Metric': 'P95 Latency', 'Latency': 22.323432661764897}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 8, 'Metric': 'Mean Latency', 'Latency': 15.116819695519837}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 8, 'Metric': 'P95 Latency', 'Latency': 21.977413365195197}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 15, 'Metric': 'Mean Latency', 'Latency': 16.61255231629395}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 15, 'Metric': 'P95 Latency', 'Latency': 21.915891756842186}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 16, 'Metric': 'Mean Latency', 'Latency': 16.796860912774786}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 16, 'Metric': 'P95 Latency', 'Latency': 22.99750641177743}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 20, 'Metric': 'Mean Latency', 'Latency': 24.095373257611712}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 20, 'Metric': 'P95 Latency', 'Latency': 33.784516672040525}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 32, 'Metric': 'Mean Latency', 'Latency': 30.50988078825887}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 32, 'Metric': 'P95 Latency', 'Latency': 45.17762461035152}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 60, 'Metric': 'Mean Latency', 'Latency': 41.67138660336526}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 60, 'Metric': 'P95 Latency', 'Latency': 66.0626247098714}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 62, 'Metric': 'Mean Latency', 'Latency': 42.48591866280657}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 62, 'Metric': 'P95 Latency', 'Latency': 67.59710822761383}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 64, 'Metric': 'Mean Latency', 'Latency': 43.25393307713577}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 64, 'Metric': 'P95 Latency', 'Latency': 69.07133427966019}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 128, 'Metric': 'Mean Latency', 'Latency': 67.68318492936268}, {'System': 'vSoC', 'Profiles': 1000, 'Concurrency': 128, 'Metric': 'P95 Latency', 'Latency': 117.0874114115515}]
df = pd.DataFrame(DATA_ROWS)
print(f"[plot] csv rows={len(df)}")



systems = ['MCon', 'Redroid', 'Anbox', 'GAE', 'vSoC']

metrics = ['Mean Latency', 'P95 Latency']



# 这里是用于对齐横坐标的配置，每个数组固定8个元素

concurrencies_mapping = {

    'MCon': [1, 2, 4, 8, 16, 32, 64, 128],

    'Redroid': [1, 2, 4, 8, 16, 32, 60, None],

    'Anbox': [1, 2, 4, 8, 16, 32, 62, None],

    'GAE': [1, 2, 4, 8, 15, None, None, None],

    'vSoC': [1, 2, 4, 8, 16, 20, None, None]

}



# 创建 2 x 5 的大画布

fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(28, 12), sharey=True)

fig.subplots_adjust(wspace=0.05, hspace=-0.2, right=0.92, left=0.08)



vmin = max(0.3, df['Latency'].min())

# Increase vmax so that the peak values map to a lighter color (the color 10^1 had previously)

vmax = 100.0 



cbar_ax = fig.add_axes([0.93, 0.15, 0.015, 0.7])



for row_idx, metric in enumerate(metrics):

    for col_idx, system in enumerate(systems):

        ax = axes[row_idx, col_idx]



        # 如果系统的展示名字是 Anbox，但 CSV 里是 Anbox Cloud，做个映射

        target_system = 'Anbox Cloud' if system == 'Anbox' else system

        subset = df[(df['System'] == target_system) & (df['Metric'] == metric)]



        # 构建透视表数据，列索引强制为 0-7

        pivot_data = {}

        x_labels_display = []

        for c_idx, c_val in enumerate(concurrencies_mapping[system]):

            if c_val is None:

                x_labels_display.append("")

                pivot_data[c_idx] = {p: np.nan for p in subset['Profiles'].unique()}

            else:

                x_labels_display.append(str(c_val))

                c_subset = subset[subset['Concurrency'] == c_val]

                pivot_data[c_idx] = {}

                for p in subset['Profiles'].unique():

                    row = c_subset[c_subset['Profiles'] == p]

                    if not row.empty:

                        pivot_data[c_idx][p] = row['Latency'].iloc[0]

                    else:

                        pivot_data[c_idx][p] = np.nan



        pivot_df = pd.DataFrame(pivot_data)

        pivot_df = pivot_df.sort_index(ascending=False)



        ax.set_facecolor("#dcdcdc")



        sns.heatmap(

            pivot_df,

            ax=ax,

            cmap="rocket_r",

            square=True,

            norm=LogNorm(vmin=vmin, vmax=vmax, clip=True),

            mask=pivot_df.isnull(),

            cbar=(row_idx == 0 and col_idx == 4),

            cbar_ax=cbar_ax if (row_idx == 0 and col_idx == 4) else None,

        )



        if row_idx == 0 or row_idx == 1:

            # Draw dark grey hatching over NA (masked) values.

            import matplotlib.patches as patches

            y_max, x_max = pivot_df.shape

            for i in range(y_max):

                for j in range(x_max):

                    if pd.isna(pivot_df.iloc[i, j]):

                        rect = patches.Rectangle((j, i), 1, 1, hatch='//', fill=False, edgecolor='dimgrey', lw=0)

                        ax.add_patch(rect)

        if row_idx == 0:

            ax.set_title(system, pad=15)



        if col_idx == 0:

            ax.set_ylabel('')

        else:

            ax.set_ylabel('')

            ax.yaxis.label.set_visible(False)

            ax.tick_params(axis='y', left=False)



        ax.set_xticks(np.arange(8) + 0.5)



        if row_idx == 1:

            ax.set_xlabel('')

            ax.set_xticklabels(x_labels_display, rotation=0, ha='center')



            # 画红圈强调物理极限

            if system != 'MCon':

                max_valid_idx = max(i for i, v in enumerate(x_labels_display) if v != "")

                ticks = ax.get_xticklabels()

                ticks[max_valid_idx].set_bbox(dict(facecolor='none', edgecolor='red', boxstyle='circle,pad=0.2', linewidth=2.5))

        else:

            ax.set_xlabel('')

            ax.xaxis.label.set_visible(False)

            ax.set_xticklabels([])

            ax.tick_params(axis='x', bottom=False)



cbar_ticks = [0.3, 0.5, 1, 3, 10, 30, 100]

cbar_ticks = [t for t in cbar_ticks if vmin <= t <= vmax]

if cbar_ticks:

    cbar_ax.set_yticks(cbar_ticks)



cbar_ax.set_ylabel('Latency (s)', fontsize=64, labelpad=20)

cbar_ax.tick_params(labelsize=36)



print(f"[plot] done total_elapsed={time.time() - t0:.2f}s")

PATH_TO_FIGURES = "./fig/"



# 这些坐标专门控制 Mean / P95 的位置：

# x 越小(更负)越往外；y 控制上下位置

MEAN_P95_X = -0.03

MEAN_Y = 0.67

P95_Y = 0.33



fig.supxlabel('Concurrency', fontsize=64, y=0.03)

fig.supylabel('Profiles', fontsize=64, x=0.01)

fig.text(MEAN_P95_X, MEAN_Y, 'Mean', fontsize=64, rotation='vertical', va='center')

fig.text(MEAN_P95_X, P95_Y, 'P95', fontsize=64, rotation='vertical', va='center')

plt.savefig(PATH_TO_FIGURES + "warmpool.pdf", format="pdf", bbox_inches="tight", pad_inches=0.1)

plt.show()
# Out:
# [plot] start, reading csv=random_latency_data.csv
# [plot] csv rows=840
# [plot] done total_elapsed=2.12s
